# %%
# !pip install langchain-groq
# Out:
# Requirement already satisfied: langchain-groq in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (0.3.4)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langchain-groq) (0.3.66)
# Requirement already satisfied: groq<1,>=0.28.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langchain-groq) (0.29.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from groq<1,>=0.28.0->langchain-groq) (4.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from groq<1,>=0.28.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from groq<1,>=0.28.0->langchain-groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from groq<1,>=0.28.0->langchain-groq) (2.11.7)
# Requirement already satisfied: sniffio in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from groq<1,>=0.28.0->langchain-groq) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from groq<1,>=0.28.0->langchain-groq) (4.12.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.28.0->langchain-groq) (1.2.0)
# Requirement already satisfied: idna>=2.8 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.28.0->langchain-groq) (3.7)
# Requirement already satisfied: certifi in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.28.0->langchain-groq) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.28.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.28.0->langchain-groq) (0.16.0)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-groq) (0.4.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-groq) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-groq) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-groq) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-groq) (24.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain-groq) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.28.0->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.28.0->langchain-groq) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.28.0->langchain-groq) (0.4.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.66->langchain-groq) (3.10.18)
# Requirement already satisfied: requests<3,>=2 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.66->langchain-groq) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.66->langchain-groq) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.66->langchain-groq) (0.23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.66->langchain-groq) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.66->langchain-groq) (2.3.0)

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(
    temperature=0, 
    groq_api_key='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', 
    model_name="llama-3.3-70b-versatile"
)
response = llm.invoke("The greatest indian actor is ...")
print(response.content)
# Out:
# That's a subjective topic. India has a rich history of talented actors, and opinions on the "greatest" can vary depending on personal taste, cultural context, and generational differences. Some notable Indian actors who are often regarded as among the greatest include:
#
# 1. Dilip Kumar: Known as the "Tragedy King," he is widely regarded as one of the greatest actors in Indian cinema.
# 2. Amitabh Bachchan: A legendary actor with a career spanning over five decades, he is often called the "Shahenshah of Bollywood."
# 3. Rajinikanth: A superstar in Tamil cinema, he is known for his unique style and has a massive following in India and abroad.
# 4. Shah Rukh Khan: Often called the "King of Bollywood," he is one of the most successful and popular actors in Indian cinema.
# 5. Naseeruddin Shah: A highly acclaimed actor known for his intense performances and contributions to Indian parallel cinema.
# 6. Kamal Haasan: A versatile actor, director, and producer who has worked in multiple languages, including Tamil, Hindi, and Telugu.
# 7. Aamir Khan: An actor, director, and producer known for his perfectionism and critically acclaimed films like "Lagaan" and "Taare Zameen Par."
#
# Of course, this is not an exhaustive list, and there are many other talented Indian actors who could be considered among the greatest. Ultimately, the "greatest" actor is a matter of personal opinion and depends on individual preferences and criteria.

# %%
# !pip install langchain-community
# Out:
# Requirement already satisfied: langchain-community in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (0.3.26)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langchain-community) (0.3.66)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langchain-community) (0.3.26)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langchain-community) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langchain-community) (3.11.10)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: langsmith>=0.1.125 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langchain-community) (0.4.4)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (4.12.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from requests<3,>=2->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from requests<3,>=2->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from requests<3,>=2->langchain-community) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from requests<3,>=2->langchain-community) (2025.4.26)
# Requirement already satisfied: greenlet>=1 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.2.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langsmith>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langsmith>=0.1.125->langchain-community) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langsmith>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from langsmith>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: anyio in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (4.7.0)
# Requirement already satisfied: httpcore==1.* in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.2.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.3.0)

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://jobs.nike.com/job/R-33460")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
# Nike Careers
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to main content
# Open Virtual Assistant
#
#
#
#
#
#
#
#
#
#
# Home
#
#
# Career Areas
#
#
# Total Rewards
#
#
# Life@Nike
#
#
# Purpose
#
#
#
#
#
#
#
#
#
#
# Language
#
#
#
#
#
# Select a Language
#
#   Deutsch
#   English
#   Español (España)
#   Español (América Latina)
#   Français
#   Italiano
#   Nederlands
#   Polski
#   Tiếng Việt
#   Türkçe
#   简体中文
#   繁體中文
#   עִברִית
#   한국어
#   日本語
#
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Close Menu
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
# Chat
#
#
#
#
#
#
#                                 Home
#
#
#
#
#                                 Career Areas
#
#
#
#
#                                 Total Rewards
#
#
#
#
#                                 Life@Nike
#
#
#
#
#                                 Purpose
#
#
#
#
#
#
#
#
#
#
#
# Jordan Careers
#
#
#
#
#
#
#
# Converse Careers
#
#
#
#
#
#
#
#
#
#
# Language
#
#
#
#
#
#
#
#
#
#
#
# Menu
#
#
#
# Return to Previous Menu
#
#
#
# Select a Language
#
#   Deutsch
#   English
#   Español (España)
#   Español (América Latina)
#   Français
#   Italiano
#   Nederlands
#   Polski
#   Tiếng Việt
#   Türkçe
#   简体中文
#   繁體中文
#   עִברִית
#   한국어
#   日本語
#
#
#
#
#
#
#
#
#
#
#
#
#                 Your browser doesn't support HTML5 video tag.
#
#
#
#
#
#
#
#
#
#
# Play Full Video
#
#
#
# WHAT MOVES YOUMOVES OUR WORLD
#
#
#
#
#
#
#
# Pause Video
#
#
#
# Play Video
#
#
#
#
#
#
# Play 'How We Do It' video
#
#
#
#
# Play 'Victory Mode' video'
#
#
#
#
# Play 'Craft the Future' video
#
#
#
#
#
#
#
#
#
#
#
# Be In the Know
#
#
#
#
#
#
#
#
#
#
# The Nike Internship Experience
# Learn More
#
#
#
#
#
#
#
#
#
#
# AI/ML Roles for Innovators
# Learn More
#
#
#
#
#
#
#
#
#
#
# Peek Into Our World
# Learn More
#
#
#
#
#
#
#
#
#
#
# NikeUNITED's Commitment
# Learn More
#
#
#
#
#
#
#
#
#
#
#
#
#
# IF YOU HAVE A BODY, YOU ARE AN ATHLETE.*
#
#
#
# These words drive who we are and what we believe in – a better future for ourselves, our communities and our athletes. We strive to bring inspiration and innovation to every athlete in the world, including our teammates.
#
#
#
#
#
#
#
#
# More Than Love of the Brand
# WHAT MOVES US
#
#
#
#
#
#
#
# Serve Athletes
#
#
#
# We believe in the power of sport. Taking ownership of our shared responsibility to action the voice of all athletes, we push ourselves and each other, turning ambition into achievement.
#
#
#
#
#
#
#
#
#
#
#
#
#
# Expand Serve Athletes Section
#
#
#
#
#
#
#
# Create the Future of Sport
#
#
#
# We understand every idea must meet a need and move people closer to their goals. That's why we're not afraid to fail - because innovation depends on risk.
#
#
#
#
#
#
#
#
#
#
#
#
#
# Expand Create the Future of Sport section
#
#
#
#
#
#
#
# Be On the Offense Always
#
#
#
# Agility is our edge. We put the consumer first by setting the pace, acting decisively and driving change to meet their
#                                             needs.
#
#
#
#
#
#
#
#
#
#
#
#
#
# Expand Be On the Offense Always section
#
#
#
#
#
#
#
# Do the Right Thing
#
#
#
# We value our unique opportunity to put ethics into action on the journey to level the playing field for all. This requires accountability, meaning we consistently make calls and own the results.
#
#
#
#
#
#
#
#
#
#
#
#
#
# Expand Do the Right Thing section
#
#
#
#
#
#
#
# Win as a Team
#
#
#
# We are strong together. Creating an environment where deep connections champion collaboration, it is expected that each player not only contributes to our collective wins but celebrates them.
#
#
#
#
#
#
#
#
#
#
#
#
#
# Expand Win as a Team section
#
#
#
#
#
#
#
#
#
#
#
#
# Go to Previous Slide
#
#
#
#
#
# Go to Next Slide
#
#
#
#
#
#
#
#
#
#
#
# Reinforcing Our Position
# CULTURE IN ACTION
# There is a sense of pride that comes from representing an iconic brand and shaping its future. Here, we treat
#                             every day
#                             as a new opportunity to push boundaries, ask tough questions and share whole-hearted convictions. We are a
#                             team – united
#                             by the belief that anything is possible.
# Learn More About Culture
#
#
#
#
#
#
#
# Elevating Your Well-Being
# FROM THE INSIDE OUT
# Rest and recovery are critical for you to be able to deliver at peak performance. You can count on us to walk
#                         the talk,
#                         providing resources and time that help keep life balanced and yourself fueled for any challenge. Compassion
#                         and
#                         flexibility enhance the supportive nature of our community.
# Learn More About Benefits
#
#
#
#
#
#
#
#
#
# Lacing Up for the Greater Good
# PURPOSE AT PLAY
# Moving the world forward through sport is no small feat. Together, we take steps to drive change by putting
#                             social
#                             impact and planet protection first. This shared passion for doing what's right fuels the NIKE, Inc. legacy
#                             and drives us
#                             forward.
# Learn
#                             More
#
#
#
#
#
#
# One Team. Iconic Brands.
# BEYOND THE SWOOSH
#
#
#
#
#
# Converse
# Bringing together those independent enough not to follow, we are catalyzing the collective power of people who see their differences as strengths. Converse is a creative team channeling ambition, expertise, and self-expression to drive innovation.
# Learn More About Converse
#
#
#
#
#
# Jordan
# Extending beyond sports into culture and fashion, Jordan Brand is bound by a commitment to serve a community representative of Michael himself. Those who make up this team thrive in an entrepreneurial environment, where creative problem-solving is leveraged to drive innovation.
#
#
#
#
#
#
# Search Jordan Careers
#
#
#
#
#
#
# Explore Careers
#
#
#
#
#
#
#
#
#
# Search Retail Careers
#
#
#
#
#
#
#
#
#
#
# Search Distribution Careers
#
#
#
#
#
#
#
#
#
#
# Search Manufacturing Careers
#
#
#
#
#
#
#
#
#
#
# Search Corporate Careers
#
#
#
#
#
#
#
#
#
#
# Search Open Internships
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# SEARCH CAREERS
#
#
#
#
# Close Modal
#
#
#
#
#
#
#
#
#                                     Apply Filters
#
#
#                                     Clear Filters
#
#
#
#
#
#
# All
#                                                 Careers
#
#
# Retail
#
#
# Distribution
#
#
# Manufacturing
#
#
# Corporate
#
#
# Internships
#
#
#
#
#
#
# Keyword SearchLocation SearchUse your locationUse your locationSearch
#
#
# Filters
#
#
#
#
# Filter ResultsCareer AreasAnalytics17Business Operations21Corporate Services4Design58Finance5Human Resources6Legal2Manufacturing12Marketing29Position TypeFull Time669Part Time239Is RemoteNo982Yes8BrandCONVERSE69JORDAN7NIKE914cf_employee_typeFixed Term Contract (Fixed Term)190Intern (Fixed Term)2Regular662Seasonal (Fixed Term) (Seasonal)122Temp Casual (Fixed Term)11Temp Trainee (Trainee)3cf_job_categoryCorporate313Distribution4Manufacturing9Retail664Clear Filter
#
#
#
#
#
#  Join The Talent Community
#
#
#
#
# Contract Jobs - USA Only*
#
#
#
#
#
#
#
#
#
#
#
#
# Edit Filters
#
#
#
#
#
#
#
#
#
# **OPERATIONS Retail Assistant ATHLETE F/T40 Hours (NIKE WEST LONDON)R-63939Job LocationWestfield White City, Shepherds Bush, London, United KingdomRetail StoresView JobACG, FW Materials Developer II ChinaR-48993Job LocationGuangzhou, Guangdong, ChinaProduct Development GroupView JobAbteilungsleiter/in (Apparel Coach) - 37.5H - Ingolstadt (m/w/d)R-59312Job LocationIngolstadt, Bavaria, GermanyRetail StoresView JobAbteilungsleiter/in (Coach) - 100% - NFS LandquartR-41112Job LocationLandquart, Graubunden, SwitzerlandRetail StoresView JobAccount Executive Jordan, PacificR-64223Job LocationMelbourne, Victoria, AustraliaSalesView JobAccounting Admin - CelebrationR-64310Job LocationKissimmee, Florida, United StatesRetail StoresView JobAccounting Admin - Deer ParkR-64345Job LocationDeer Park, New York, United StatesRetail StoresView JobAccounting Admin - DolphinR-64380Job LocationMiami, Florida, United StatesRetail StoresView JobAccounting/Administrative Assistant - Edinburgh, INR-57501Job LocationEdinburgh, Indiana, United StatesRetail StoresView JobAddetto vendite/Athlete (JOC) - Contratto a chiamata NUS CASTEL ROMANOR-60565Job LocationCastel Romano, Roma, ItalyRetail StoresView Job
# 1020Go to first pageGo to previous page12345678910Go to next pageGo to last page
#
#
#
#
#
#
#
#
#
#
#
# Close
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Home
#
#
# About Us
#
#
# Contact
#
#
# Talent Community
#
#
# Terms
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     Nike Applicant Privacy Policy
#
#
#
#
#
#
# We offer a number of accommodations to complete our interview process including screen readers, sign language interpreters,
#                 accessible and single location for in-person interviews, closed captioning, and other reasonable modifications as
#                 needed.
#
#
# If you discover, as you navigate our application process, that you need assistance or an accommodation due to a
#                 disability, please contact us at +1 503-671-4156 and include your full name, best way to reach you, and the
#                 accommodation you request to assist with the application process.
# For more information, please refer to Equal Employment
#                         Opportunity is The Law.
#
#
#
# ©  Nike, Inc. All Rights Reserved
#
#
#
#
#
#
#
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
#
#
# Chat
# Chat with our AI Assistant

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
        """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the 
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):    
        """
)

chain_extract = prompt_extract | llm 
res = chain_extract.invoke(input={'page_data':page_data})
type(res.content)
# Out:
# str

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# [{'role': 'OPERATIONS Retail Assistant ATHLETE F/T40 Hours',
#   'experience': 'Full Time',
#   'skills': '',
#   'description': 'NIKE WEST LONDON'},
#  {'role': 'ACG, FW Materials Developer II',
#   'experience': '',
#   'skills': '',
#   'description': 'China'},
#  {'role': 'Abteilungsleiter/in (Apparel Coach)',
#   'experience': '',
#   'skills': '',
#   'description': '37.5H - Ingolstadt (m/w/d)'},
#  {'role': 'Abteilungsleiter/in (Coach)',
#   'experience': '',
#   'skills': '',
#   'description': '100% - NFS Landquart'},
#  {'role': 'Account Executive Jordan, Pacific',
#   'experience': '',
#   'skills': '',
#   'description': 'Melbourne, Victoria, Australia'},
#  {'role': 'Accounting Admin',
#   'experience': '',
#   'skills': '',
#   'description': 'Celebration'},
#  {'role': 'Accounting Admin',
#   'experience': '',
#   'skills': '',
#   'description': 'Deer Park'},
#  {'role': 'Accounting Admin',
#   'experience': '',
#   'skills': '',
#   'description': 'Dolphin'},
#  {'role': 'Accounting/Administrative Assistant',
#   'experience': '',
#   'skills': '',
#   'description': 'Edinburgh, IN'},
#  {'role': 'Addetto vendite/Athlete (JOC)',
#   'experience': '',
#   'skills': '',
#   'description': 'Contratto a chiamata NUS CASTEL ROMANO'}]

# %%
type(json_res)
# Out:
# list

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (2.3.0)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

df = pd.read_csv("my_portfolio.csv")
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# 0                 https://example.com/react-portfolio
# 1               https://example.com/angular-portfolio
# 2                   https://example.com/vue-portfolio
# 3                https://example.com/python-portfolio
# 4                  https://example.com/java-portfolio
# 5               https://example.com/flutter-portfolio
# 6             https://example.com/wordpress-portfolio
# 7               https://example.com/magento-portfolio
# 8          https://example.com/react-native-portfolio
# 9                   https://example.com/ios-portfolio
# 10              https://example.com/android-portfolio
# 11       https://example.com/kotlin-android-portfolio
# 12           https://example.com/android-tv-portfolio
# 13               https://example.com/ios-ar-portfolio
# 14              https://example.com/xamarin-portfolio
# 15       https://example.com/kotlin-backend-portfolio
# 16  https://example.com/typescript-frontend-portfolio
# 17        https://example.com/full-stack-js-portfolio
# 18            https://example.com/ml-python-portfolio
# 19               https://example.com/devops-portfolio

# %%
# !pip install --upgrade chromadb
# Out:
# Requirement already satisfied: chromadb in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (1.0.13)
# Requirement already satisfied: build>=1.0.3 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from chromadb) (2.11.7)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from chromadb) (1.4.1)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.35.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from chromadb) (2.0.2)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from chromadb) (6.0.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from chromadb) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from chromadb) (1.19.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from chromadb) (1.34.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from chromadb) (0.21.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from chromadb) (1.73.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from chromadb) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from chromadb) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from chromadb) (3.10.18)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from chromadb) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: packaging>=19.1 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from build>=1.0.3->chromadb) (24.2)
# Requirement already satisfied: pyproject_hooks in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from build>=1.0.3->chromadb) (8.5.0)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: anyio in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from httpx>=0.27.0->chromadb) (4.7.0)
# Requirement already satisfied: certifi in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from httpx>=0.27.0->chromadb) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from httpx>=0.27.0->chromadb) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from importlib-metadata>=4.6->build>=1.0.3->chromadb) (3.21.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from jsonschema>=4.19.0->chromadb) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.22.3)
# Requirement already satisfied: six>=1.9.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.35.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Requirement already satisfied: requests-oauthlib in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.3.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: setuptools>=40.3.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (78.1.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.7.2)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Requirement already satisfied: coloredlogs in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Requirement already satisfied: protobuf in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.5)
# Requirement already satisfied: sympy in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.55b1)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from posthog>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.3.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from pydantic>=1.9->chromadb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from pydantic>=1.9->chromadb) (0.4.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.33.1)
# Requirement already satisfied: filelock in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.5.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.2.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\abhigyan borah\.conda\envs\vid\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)

# %%
import os
os.environ["CHROMA_TELEMETRY"] = "False"

# %%
import os
os.environ["CHROMA_TELEMETRY"] = "False"

import uuid
import chromadb

client = chromadb.PersistentClient(path='vectorstore')  # ✅ CORRECT usage
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(
            documents=[row["Techstack"]],
            metadatas=[{"links": row["Links"]}],
            ids=[str(uuid.uuid4())]
        )
# Out:
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given

# %%
links = collection.query(
    query_texts=["Experience in Python", "Experience in React"],
    n_results=2
).get('metadatas', [])

print(links)
# Out:
# [[{'links': 'https://example.com/ml-python-portfolio'}, {'links': 'https://example.com/python-portfolio'}], [{'links': 'https://example.com/react-portfolio'}, {'links': 'https://example.com/react-native-portfolio'}]]

# %%
job
# Out:
# [{'role': 'Software Engineer (L6) - Cloud Infra Abstractions',
#   'experience': 'L6',
#   'skills': [],
#   'description': ''}]

# %%
print(type(json_res))
print(json_res)
# Out:
# <class 'list'>
# [{'role': 'OPERATIONS Retail Assistant ATHLETE F/T40 Hours', 'experience': 'Full Time', 'skills': '', 'description': 'NIKE WEST LONDON'}, {'role': 'ACG, FW Materials Developer II', 'experience': '', 'skills': '', 'description': 'China'}, {'role': 'Abteilungsleiter/in (Apparel Coach)', 'experience': '', 'skills': '', 'description': '37.5H - Ingolstadt (m/w/d)'}, {'role': 'Abteilungsleiter/in (Coach)', 'experience': '', 'skills': '', 'description': '100% - NFS Landquart'}, {'role': 'Account Executive Jordan, Pacific', 'experience': '', 'skills': '', 'description': 'Melbourne, Victoria, Australia'}, {'role': 'Accounting Admin', 'experience': '', 'skills': '', 'description': 'Celebration'}, {'role': 'Accounting Admin', 'experience': '', 'skills': '', 'description': 'Deer Park'}, {'role': 'Accounting Admin', 'experience': '', 'skills': '', 'description': 'Dolphin'}, {'role': 'Accounting/Administrative Assistant', 'experience': '', 'skills': '', 'description': 'Edinburgh, IN'}, {'role': 'Addetto vendite/Athlete (JOC)', 'experience': '', 'skills': '', 'description': 'Contratto a chiamata NUS CASTEL ROMANO'}]

# %%
job = json_res
job["skills"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 2
#       1 job = json_res
# ----> 2 job["skills"]
#
# TypeError: list indices must be integers or slices, not str

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}
        
        ### INSTRUCTION:
        You are Mohan, a business development executive at AtliQ. AtliQ is an AI & Software Consulting company dedicated to facilitating
        the seamless integration of business processes through automated tools. 
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability, 
        process optimization, cost reduction, and heightened overall efficiency. 
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of AtliQ 
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase Atliq's portfolio: {link_list}
        Remember you are Mohan, BDE at AtliQ. 
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):
        
        """
        )

chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# Subject: Enhance Operational Efficiency with AtliQ's Automated Solutions
#
# Dear Hiring Manager,
#
# I came across the job postings for various roles at Nike, including OPERATIONS Retail Assistant ATHLETE F/T40 Hours, ACG, FW Materials Developer II, and others. As a business development executive at AtliQ, I believe our company can help streamline your business processes and enhance operational efficiency.
#
# At AtliQ, we specialize in providing tailored solutions to facilitate the seamless integration of business processes through automated tools. Our expertise in AI and software consulting has empowered numerous enterprises to achieve scalability, process optimization, cost reduction, and heightened overall efficiency.
#
# Our portfolio showcases our capabilities in machine learning and Python development, which can be applied to various aspects of your operations, such as supply chain management, inventory control, and sales forecasting. For instance, our machine learning solutions can help predict demand and optimize inventory levels, while our Python development expertise can automate tasks and improve data analysis. You can explore our relevant projects at https://example.com/ml-python-portfolio and https://example.com/python-portfolio.
#
# Additionally, our experience in React and React Native development can help you create customized web and mobile applications to enhance customer engagement and improve sales. Our React portfolio (https://example.com/react-portfolio) and React Native portfolio (https://example.com/react-native-portfolio) demonstrate our ability to deliver high-quality, user-friendly applications that can help you stay ahead of the competition.
#
# I would be delighted to discuss how AtliQ's automated solutions can address your specific needs and challenges. Please let me know if you would like to schedule a call to explore further.
#
# Best regards,
# Mohan
# Business Development Executive
# AtliQ
